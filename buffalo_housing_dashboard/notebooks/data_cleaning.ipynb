# %%
import pandas as pd
df_apart= pd.read_csv("../Data/apartments.csv")
#df_apart.head(10)
print("Apartments.com columns:")
print(df_apart.columns.tolist())
# Out:
# Apartments.com columns:
# ['Title', 'Price', 'Address', 'Beds', 'URL']

# %%
import pandas as pd
df_pad= pd.read_csv("../Data/padmapper.csv")
#df_pad.head(10)
print("\nPadmapper.com columns:")
print(df_pad.columns.tolist())
# Out:
# Padmapper.com columns:
# ['address', 'price', 'bedrooms', 'area', 'url']

# %%
df_pad_renamed = df_pad.rename(columns={'address': 'Title', 'price': 'Price', 'bedrooms':'Beds', 'area':'Address', 'url':'URL'})

print(df_pad_renamed.columns.tolist())
# Out:
# ['Title', 'Price', 'Beds', 'Address', 'URL']

# %%
df_pad_renamed.info()
df_apart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Title    400 non-null    object
#  1   Price    400 non-null    object
#  2   Beds     400 non-null    object
#  3   Address  400 non-null    object
#  4   URL      400 non-null    object
# dtypes: object(5)
# memory usage: 15.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Title    365 non-null    object
#  1   Price    365 non-null    object
#  2   Address  365 non-null    object
#  3   Beds     365 non-null    object
#  4   URL      365 non-null    object
# dtypes: object(5)
# memory usage: 14.4+ KB

# %%
import numpy as np
import pandas as pd

def split_range_column(series, sep='-', is_price=True):
    result = []
    for val in series:
        s = str(val).strip().lower()
        if is_price:
            s = s.replace('$','').replace(',','')
        s = s.replace('beds','').replace('bed','').replace('studio','0').replace(' ', '')
        
        # Split on en dash or hyphen
        if '–' in s:
            left, right = s.split('–',1)
        elif sep in s:
            left, right = s.split(sep,1)
        else:
            left = right = s
        
        try:
            min_val = float(left)
            max_val = float(right)
        except:
            min_val = max_val = np.nan
        
        result.append((min_val, max_val))
    
    arr = np.array(result)
    return pd.Series(arr[:,0]), pd.Series(arr[:,1])

# ----------------------------
# Apply split to both datasets
# ----------------------------
for df in [df_apart, df_pad_renamed]:
    df['price_min'], df['price_max'] = split_range_column(df['Price'], is_price=True)
    df['beds_min'], df['beds_max'] = split_range_column(df['Beds'], is_price=False)


from IPython.display import display

display(df_apart.head(10))      # Show apartments.com data
print("\n--- Padmapper ---\n")
display(df_pad_renamed.head(10))   # Show padmapper.com data
# Out:
#                            Title            Price  \
# 0      Trico Building Apartments  $1,575 - $3,470
# 1                         Park75  $1,049 - $1,999
# 2                       The Grid  $1,239 - $2,200
# 3                      The Rails  $1,435 - $2,079
# 4        The John Kam Malt House  $1,450 - $2,629
# 5      Michigan Place Apartments  $1,239 - $1,999
# 6                Kaymar Duplexes  $1,645 - $1,745
# 7  Playter Gardens at the Market    Call for Rent
# 8             Peace Bridge Place  $1,045 - $1,320
# 9      Windsong Place Apartments  $1,496 - $2,486
#
#                                   Address             Beds  \
# 0      628 Ellicott St, Buffalo, NY 14203  Studio - 3 Beds
# 1    1175 Delaware Ave, Buffalo, NY 14209  Studio - 2 Beds
# 2         1155 Main St, Buffalo, NY 14209  Studio - 2 Beds
# 3         2939 Main St, Buffalo, NY 14214         1-2 Beds
# 4       356 Hertel Ave, Buffalo, NY 14207         1-2 Beds
# 5    1145 Michigan Ave, Buffalo, NY 14209  Studio - 2 Beds
# 6        301 Kaymar Dr, Buffalo, NY 14228           3 Beds
# 7   107-229 Playter St, Buffalo, NY 14212           2 Beds
# 8       111 Porter Ave, Buffalo, NY 14201   Studio - 1 Bed
# 9  25 Spring Meadow Dr, Buffalo, NY 14221         1-3 Beds
#
#                                                  URL  price_min  price_max  \
# 0  https://www.apartments.com/trico-building-apar...     1575.0     3470.0
# 1  https://www.apartments.com/park75-buffalo-ny/7...     1049.0     1999.0
# 2  https://www.apartments.com/the-grid-buffalo-ny...     1239.0     2200.0
# 3  https://www.apartments.com/the-rails-buffalo-n...     1435.0     2079.0
# 4  https://www.apartments.com/the-john-kam-malt-h...     1450.0     2629.0
# 5  https://www.apartments.com/michigan-place-apar...     1239.0     1999.0
# 6  https://www.apartments.com/kaymar-duplexes-buf...     1645.0     1745.0
# 7  https://www.apartments.com/playter-gardens-at-...        NaN        NaN
# 8  https://www.apartments.com/peace-bridge-place-...     1045.0     1320.0
# 9  https://www.apartments.com/windsong-place-apar...     1496.0     2486.0
#
#    beds_min  beds_max
# 0       0.0       3.0
# 1       0.0       2.0
# 2       0.0       2.0
# 3       1.0       2.0
# 4       1.0       2.0
# 5       0.0       2.0
# 6       3.0       3.0
# 7       2.0       2.0
# 8       0.0       1.0
# 9       1.0       3.0
# --- Padmapper ---
#                              Title          Price    Beds  \
# 0            Wood and Brooks Lofts  $1,595–$2,200     1–2
# 1  The Residences at Linwood Manor         $1,150  Studio
# 2                 128 Pearl Street  $1,475–$2,325     1–2
# 3             210 Ellicott St #304         $2,250       2
# 4                 234 Crescent Ave         $1,195       2
# 5         Griffin House Apartments  $1,175–$1,630     1–2
# 6           Colvin View Apartments         $1,225       2
# 7             2 Niagara Falls Blvd         $3,544       4
# 8           110 Bidwell Parkway #2         $1,500       1
# 9              116 Bidwell Parkway         $1,150       1
#
#                               Address  \
# 0             Riverside Park, Buffalo
# 1      Delaware - West Ferry, Buffalo
# 2  Central Business District, Buffalo
# 3  Central Business District, Buffalo
# 4                   Parkside, Buffalo
# 5                   Parkside, Buffalo
# 6                 North Park, Buffalo
# 7                 University, Buffalo
# 8                     Forest, Buffalo
# 9                     Forest, Buffalo
#
#                                                  URL  price_min  price_max  \
# 0  https://www.padmapper.com/buildings/p1238897/w...     1595.0     2200.0
# 1  https://www.padmapper.com/buildings/p1126416/t...     1150.0     1150.0
# 2  https://www.padmapper.com/buildings/p1385653/a...     1475.0     2325.0
# 3  https://www.padmapper.com/rentals/12910508p/2-...     2250.0     2250.0
# 4  https://www.padmapper.com/rentals/23377913p/2-...     1195.0     1195.0
# 5  https://www.padmapper.com/buildings/p1126417/g...     1175.0     1630.0
# 6  https://www.padmapper.com/buildings/p1168892/c...     1225.0     1225.0
# 7  https://www.padmapper.com/rentals/62459107/4-b...     3544.0     3544.0
# 8  https://www.padmapper.com/rentals/62678776/1-b...     1500.0     1500.0
# 9  https://www.padmapper.com/rentals/26673279p/1-...     1150.0     1150.0
#
#    beds_min  beds_max
# 0       1.0       2.0
# 1       0.0       0.0
# 2       1.0       2.0
# 3       2.0       2.0
# 4       2.0       2.0
# 5       1.0       2.0
# 6       2.0       2.0
# 7       4.0       4.0
# 8       1.0       1.0
# 9       1.0       1.0

# %%
# ----------------------------
# Fill missing values
# ----------------------------
# Apartments.com → fill based on beds
def fill_rent_based_on_beds(row):
    beds = row['beds_min']
    if beds == 1:
        return 1220
    elif beds == 2:
        return 1460
    else:
        return 1375

for col in ['price_min','price_max']:
    df_apart[col] = df_apart[col].fillna(df_apart.apply(fill_rent_based_on_beds, axis=1))

df_apart['beds_min'] = df_apart['beds_min'].fillna(1)
df_apart['beds_max'] = df_apart['beds_max'].fillna(df_apart['beds_min'])

# Padmapper → fill missing prices with median
median_price_min = df_pad_renamed['price_min'].median()
median_price_max = df_pad_renamed['price_max'].median()
df_pad_renamed['price_min'] = df_pad_renamed['price_min'].fillna(median_price_min)
df_pad_renamed['price_max'] = df_pad_renamed['price_max'].fillna(median_price_max)

df_pad_renamed['beds_min'] = df_pad_renamed['beds_min'].fillna(1)
df_pad_renamed['beds_max'] = df_pad_renamed['beds_max'].fillna(df_pad_renamed['beds_min'])


from IPython.display import display

display(df_apart.head(10))      # Show apartments.com data
print("\n--- Padmapper ---\n")
display(df_pad_renamed.head(10))   # Show padmapper.com data
# Out:
#                            Title            Price  \
# 0      Trico Building Apartments  $1,575 - $3,470
# 1                         Park75  $1,049 - $1,999
# 2                       The Grid  $1,239 - $2,200
# 3                      The Rails  $1,435 - $2,079
# 4        The John Kam Malt House  $1,450 - $2,629
# 5      Michigan Place Apartments  $1,239 - $1,999
# 6                Kaymar Duplexes  $1,645 - $1,745
# 7  Playter Gardens at the Market    Call for Rent
# 8             Peace Bridge Place  $1,045 - $1,320
# 9      Windsong Place Apartments  $1,496 - $2,486
#
#                                   Address             Beds  \
# 0      628 Ellicott St, Buffalo, NY 14203  Studio - 3 Beds
# 1    1175 Delaware Ave, Buffalo, NY 14209  Studio - 2 Beds
# 2         1155 Main St, Buffalo, NY 14209  Studio - 2 Beds
# 3         2939 Main St, Buffalo, NY 14214         1-2 Beds
# 4       356 Hertel Ave, Buffalo, NY 14207         1-2 Beds
# 5    1145 Michigan Ave, Buffalo, NY 14209  Studio - 2 Beds
# 6        301 Kaymar Dr, Buffalo, NY 14228           3 Beds
# 7   107-229 Playter St, Buffalo, NY 14212           2 Beds
# 8       111 Porter Ave, Buffalo, NY 14201   Studio - 1 Bed
# 9  25 Spring Meadow Dr, Buffalo, NY 14221         1-3 Beds
#
#                                                  URL  price_min  price_max  \
# 0  https://www.apartments.com/trico-building-apar...     1575.0     3470.0
# 1  https://www.apartments.com/park75-buffalo-ny/7...     1049.0     1999.0
# 2  https://www.apartments.com/the-grid-buffalo-ny...     1239.0     2200.0
# 3  https://www.apartments.com/the-rails-buffalo-n...     1435.0     2079.0
# 4  https://www.apartments.com/the-john-kam-malt-h...     1450.0     2629.0
# 5  https://www.apartments.com/michigan-place-apar...     1239.0     1999.0
# 6  https://www.apartments.com/kaymar-duplexes-buf...     1645.0     1745.0
# 7  https://www.apartments.com/playter-gardens-at-...     1460.0     1460.0
# 8  https://www.apartments.com/peace-bridge-place-...     1045.0     1320.0
# 9  https://www.apartments.com/windsong-place-apar...     1496.0     2486.0
#
#    beds_min  beds_max
# 0       0.0       3.0
# 1       0.0       2.0
# 2       0.0       2.0
# 3       1.0       2.0
# 4       1.0       2.0
# 5       0.0       2.0
# 6       3.0       3.0
# 7       2.0       2.0
# 8       0.0       1.0
# 9       1.0       3.0
# --- Padmapper ---
#                              Title          Price    Beds  \
# 0            Wood and Brooks Lofts  $1,595–$2,200     1–2
# 1  The Residences at Linwood Manor         $1,150  Studio
# 2                 128 Pearl Street  $1,475–$2,325     1–2
# 3             210 Ellicott St #304         $2,250       2
# 4                 234 Crescent Ave         $1,195       2
# 5         Griffin House Apartments  $1,175–$1,630     1–2
# 6           Colvin View Apartments         $1,225       2
# 7             2 Niagara Falls Blvd         $3,544       4
# 8           110 Bidwell Parkway #2         $1,500       1
# 9              116 Bidwell Parkway         $1,150       1
#
#                               Address  \
# 0             Riverside Park, Buffalo
# 1      Delaware - West Ferry, Buffalo
# 2  Central Business District, Buffalo
# 3  Central Business District, Buffalo
# 4                   Parkside, Buffalo
# 5                   Parkside, Buffalo
# 6                 North Park, Buffalo
# 7                 University, Buffalo
# 8                     Forest, Buffalo
# 9                     Forest, Buffalo
#
#                                                  URL  price_min  price_max  \
# 0  https://www.padmapper.com/buildings/p1238897/w...     1595.0     2200.0
# 1  https://www.padmapper.com/buildings/p1126416/t...     1150.0     1150.0
# 2  https://www.padmapper.com/buildings/p1385653/a...     1475.0     2325.0
# 3  https://www.padmapper.com/rentals/12910508p/2-...     2250.0     2250.0
# 4  https://www.padmapper.com/rentals/23377913p/2-...     1195.0     1195.0
# 5  https://www.padmapper.com/buildings/p1126417/g...     1175.0     1630.0
# 6  https://www.padmapper.com/buildings/p1168892/c...     1225.0     1225.0
# 7  https://www.padmapper.com/rentals/62459107/4-b...     3544.0     3544.0
# 8  https://www.padmapper.com/rentals/62678776/1-b...     1500.0     1500.0
# 9  https://www.padmapper.com/rentals/26673279p/1-...     1150.0     1150.0
#
#    beds_min  beds_max
# 0       1.0       2.0
# 1       0.0       0.0
# 2       1.0       2.0
# 3       2.0       2.0
# 4       2.0       2.0
# 5       1.0       2.0
# 6       2.0       2.0
# 7       4.0       4.0
# 8       1.0       1.0
# 9       1.0       1.0

# %%
# ----------------------------
# Combine datasets
# ----------------------------
import pandas as pd

# Adding a column to track source
df_apart['Source'] = 'apartments.com'
df_pad_renamed['Source'] = 'padmapper.com'

# Merge the datasets (stack them vertically)
df_merged = pd.concat([df_apart, df_pad_renamed], ignore_index=True)

# Reorder columns if you like
cols_order = ['Source', 'Title','Address','URL','Price','Beds','price_min','price_max','beds_min','beds_max']
df_merged = df_merged[cols_order]

# Save to CSV
df_merged.to_csv("../Data/merged.csv", index=False)

# Check
print(df_merged.head(10))
print("\nMissing values check:")
print(df_merged.isnull().sum())
# Out:
#            Source                          Title  \
# 0  apartments.com      Trico Building Apartments
# 1  apartments.com                         Park75
# 2  apartments.com                       The Grid
# 3  apartments.com                      The Rails
# 4  apartments.com        The John Kam Malt House
# 5  apartments.com      Michigan Place Apartments
# 6  apartments.com                Kaymar Duplexes
# 7  apartments.com  Playter Gardens at the Market
# 8  apartments.com             Peace Bridge Place
# 9  apartments.com      Windsong Place Apartments
#
#                                   Address  \
# 0      628 Ellicott St, Buffalo, NY 14203
# 1    1175 Delaware Ave, Buffalo, NY 14209
# 2         1155 Main St, Buffalo, NY 14209
# 3         2939 Main St, Buffalo, NY 14214
# 4       356 Hertel Ave, Buffalo, NY 14207
# 5    1145 Michigan Ave, Buffalo, NY 14209
# 6        301 Kaymar Dr, Buffalo, NY 14228
# 7   107-229 Playter St, Buffalo, NY 14212
# 8       111 Porter Ave, Buffalo, NY 14201
# 9  25 Spring Meadow Dr, Buffalo, NY 14221
#
#                                                  URL            Price  \
# 0  https://www.apartments.com/trico-building-apar...  $1,575 - $3,470
# 1  https://www.apartments.com/park75-buffalo-ny/7...  $1,049 - $1,999
# 2  https://www.apartments.com/the-grid-buffalo-ny...  $1,239 - $2,200
# 3  https://www.apartments.com/the-rails-buffalo-n...  $1,435 - $2,079
# 4  https://www.apartments.com/the-john-kam-malt-h...  $1,450 - $2,629
# 5  https://www.apartments.com/michigan-place-apar...  $1,239 - $1,999
# 6  https://www.apartments.com/kaymar-duplexes-buf...  $1,645 - $1,745
# 7  https://www.apartments.com/playter-gardens-at-...    Call for Rent
# 8  https://www.apartments.com/peace-bridge-place-...  $1,045 - $1,320
# 9  https://www.apartments.com/windsong-place-apar...  $1,496 - $2,486
#
#               Beds  price_min  price_max  beds_min  beds_max
# 0  Studio - 3 Beds     1575.0     3470.0       0.0       3.0
# 1  Studio - 2 Beds     1049.0     1999.0       0.0       2.0
# 2  Studio - 2 Beds     1239.0     2200.0       0.0       2.0
# 3         1-2 Beds     1435.0     2079.0       1.0       2.0
# 4         1-2 Beds     1450.0     2629.0       1.0       2.0
# 5  Studio - 2 Beds     1239.0     1999.0       0.0       2.0
# 6           3 Beds     1645.0     1745.0       3.0       3.0
# 7           2 Beds     1460.0     1460.0       2.0       2.0
# 8   Studio - 1 Bed     1045.0     1320.0       0.0       1.0
# 9         1-3 Beds     1496.0     2486.0       1.0       3.0
#
# Missing values check:
# Source       0
# Title        0
# Address      0
# URL          0
# Price        0
# Beds         0
# price_min    0
# price_max    0
# beds_min     0
# beds_max     0
# dtype: int64

# %%
print(df_merged.head(10))
# Out:
#            Source                          Title  \
# 0  apartments.com      Trico Building Apartments
# 1  apartments.com                         Park75
# 2  apartments.com                       The Grid
# 3  apartments.com                      The Rails
# 4  apartments.com        The John Kam Malt House
# 5  apartments.com      Michigan Place Apartments
# 6  apartments.com                Kaymar Duplexes
# 7  apartments.com  Playter Gardens at the Market
# 8  apartments.com             Peace Bridge Place
# 9  apartments.com      Windsong Place Apartments
#
#                                   Address  \
# 0      628 Ellicott St, Buffalo, NY 14203
# 1    1175 Delaware Ave, Buffalo, NY 14209
# 2         1155 Main St, Buffalo, NY 14209
# 3         2939 Main St, Buffalo, NY 14214
# 4       356 Hertel Ave, Buffalo, NY 14207
# 5    1145 Michigan Ave, Buffalo, NY 14209
# 6        301 Kaymar Dr, Buffalo, NY 14228
# 7   107-229 Playter St, Buffalo, NY 14212
# 8       111 Porter Ave, Buffalo, NY 14201
# 9  25 Spring Meadow Dr, Buffalo, NY 14221
#
#                                                  URL            Price  \
# 0  https://www.apartments.com/trico-building-apar...  $1,575 - $3,470
# 1  https://www.apartments.com/park75-buffalo-ny/7...  $1,049 - $1,999
# 2  https://www.apartments.com/the-grid-buffalo-ny...  $1,239 - $2,200
# 3  https://www.apartments.com/the-rails-buffalo-n...  $1,435 - $2,079
# 4  https://www.apartments.com/the-john-kam-malt-h...  $1,450 - $2,629
# 5  https://www.apartments.com/michigan-place-apar...  $1,239 - $1,999
# 6  https://www.apartments.com/kaymar-duplexes-buf...  $1,645 - $1,745
# 7  https://www.apartments.com/playter-gardens-at-...    Call for Rent
# 8  https://www.apartments.com/peace-bridge-place-...  $1,045 - $1,320
# 9  https://www.apartments.com/windsong-place-apar...  $1,496 - $2,486
#
#               Beds  price_min  price_max  beds_min  beds_max
# 0  Studio - 3 Beds     1575.0     3470.0       0.0       3.0
# 1  Studio - 2 Beds     1049.0     1999.0       0.0       2.0
# 2  Studio - 2 Beds     1239.0     2200.0       0.0       2.0
# 3         1-2 Beds     1435.0     2079.0       1.0       2.0
# 4         1-2 Beds     1450.0     2629.0       1.0       2.0
# 5  Studio - 2 Beds     1239.0     1999.0       0.0       2.0
# 6           3 Beds     1645.0     1745.0       3.0       3.0
# 7           2 Beds     1460.0     1460.0       2.0       2.0
# 8   Studio - 1 Bed     1045.0     1320.0       0.0       1.0
# 9         1-3 Beds     1496.0     2486.0       1.0       3.0
